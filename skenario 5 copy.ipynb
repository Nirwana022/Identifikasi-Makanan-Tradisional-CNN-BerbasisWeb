# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import backend as K
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
from tensorflow.keras.layers import Dense, Activation,Dropout,Conv2D, MaxPooling2D,BatchNormalization, Flatten,Input
from tensorflow.keras.optimizers import Adam, Adamax
from tensorflow.keras.metrics import categorical_crossentropy
from tensorflow.keras import regularizers
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.models import Model, load_model, Sequential
from keras.callbacks import ModelCheckpoint
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt
from matplotlib.pyplot import imshow
import os
import seaborn as sns
sns.set_style('darkgrid')
from sklearn.metrics import confusion_matrix, classification_report
from IPython.display import display, HTML

# %% [markdown]
# ### iterate through the folders to create a dataframe of the form filepaths labels

# %%
sdir=r'/Users/nirwanaamir/Downloads/dataset-2'


filepaths=[]
labels=[]
classlist=os.listdir(sdir)
for klass in classlist:
    classpath=os.path.join(sdir,klass)
    if os.path.isdir(classpath):
        flist=os.listdir(classpath)
        for f in flist:
            fpath=os.path.join(classpath,f)
            filepaths.append(fpath)
            labels.append(klass)                   
Fseries= pd.Series(filepaths, name='filepaths')
Lseries=pd.Series(labels, name='labels')    
df=pd.concat([Fseries, Lseries], axis=1)
print (df.head())
print (df['labels'].value_counts())
# Out:
#                                            filepaths              labels
# 0  /Users/nirwanaamir/Downloads/dataset-2/Ayam Wo...  Ayam Woku (Manado)
# 1  /Users/nirwanaamir/Downloads/dataset-2/Ayam Wo...  Ayam Woku (Manado)
# 2  /Users/nirwanaamir/Downloads/dataset-2/Ayam Wo...  Ayam Woku (Manado)
# 3  /Users/nirwanaamir/Downloads/dataset-2/Ayam Wo...  Ayam Woku (Manado)
# 4  /Users/nirwanaamir/Downloads/dataset-2/Ayam Wo...  Ayam Woku (Manado)
# labels
# Ayam Woku (Manado)             50
# Mie Titi(Makassar)             50
# Deppa Tori_ (Toraja)           50
# Konro (Makassar)               50
# Coto Makassar (Makassar)       50
# Pisang Ijo (Makassar)          50
# Kasuami (Wakatobi)             50
# Kue Tetu(Sulawesi Barat)       50
# Cakalang Pampis (Manado)       50
# Bubur Manado (Manado)          50
# Lawa Bale (Palopo)             50
# Panada (Sulawesi  Utara)       50
# Kapurung (Palopo)              50
# Barongko (Sulawesi Selatan)    50
# Nasu Palekko (Pinrang)         50
# Lalampa(Sulawesi Tengah)       50
# Pa_piong (Toraja)              50
# klappertaart (Manado)          50
# Lapa-Lapa (Buton)              50
# Jagung Marning (Bulukumba)     50
# Name: count, dtype: int64

# %% [markdown]
# ### split df into train_df, test_df and valid_df

# %%
train_split=.7
test_split=.2
dummy_split=test_split/(1-train_split)
train_df, dummy_df=train_test_split(df, train_size=train_split, shuffle=True, random_state=123)
test_df, valid_df=train_test_split(dummy_df, train_size=dummy_split, shuffle=True, random_state=123)
print ('train_df length: ', len(train_df), '  test_df length: ', len(test_df), '  valid_df length: ', len(valid_df))
# Out:
# train_df length:  700   test_df length:  200   valid_df length:  100

# %% [markdown]
# ### create train, test, valid  generators

# %%
height=224
width=224
channels=3
batch_size=64
img_shape=(height, width, channels)
img_size=(height, width)

length=len(test_df)
test_batch_size=sorted([int(length/n) for n in range(1,length+1) if length % n ==0 and length/n<=80],reverse=True)[0]  
test_steps=int(length/test_batch_size)
print ( 'test batch size: ' ,test_batch_size, '  test steps: ', test_steps)

gen=ImageDataGenerator(rescale=1./255, shear_range=0.2, zoom_range=0.2, rotation_range=30, horizontal_flip=True)



train_gen=gen.flow_from_dataframe( train_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=True, batch_size=batch_size)

validgen=ImageDataGenerator(rescale=1./255)
valid_gen=validgen.flow_from_dataframe( valid_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=True, batch_size=batch_size)

testgen=ImageDataGenerator(rescale=1./255)
test_gen=testgen.flow_from_dataframe( test_df, x_col='filepaths', y_col='labels', target_size=img_size, class_mode='categorical',
                                    color_mode='rgb', shuffle=False, batch_size=test_batch_size)

classes=list(train_gen.class_indices.keys())
print (classes)
class_count=len(classes)
# Out:
# test batch size:  50   test steps:  4
# Found 700 validated image filenames belonging to 20 classes.
# Found 100 validated image filenames belonging to 20 classes.
# Found 200 validated image filenames belonging to 20 classes.
# ['Ayam Woku (Manado)', 'Barongko (Sulawesi Selatan)', 'Bubur Manado (Manado)', 'Cakalang Pampis (Manado)', 'Coto Makassar (Makassar)', 'Deppa Tori_ (Toraja)', 'Jagung Marning (Bulukumba)', 'Kapurung (Palopo)', 'Kasuami (Wakatobi)', 'Konro (Makassar)', 'Kue Tetu(Sulawesi Barat)', 'Lalampa(Sulawesi Tengah)', 'Lapa-Lapa (Buton)', 'Lawa Bale (Palopo)', 'Mie Titi(Makassar)', 'Nasu Palekko (Pinrang)', 'Pa_piong (Toraja)', 'Panada (Sulawesi  Utara)', 'Pisang Ijo (Makassar)', 'klappertaart (Manado)']

# %% [markdown]
# ### create function to show some image examples

# %%
def show_image_samples_filenames(gen):
    filenames = gen.filenames
    print("Filenames of images in the testing dataset:")
    for filename in filenames:
        print(filename)

# Display filenames of images in the testing dataset
show_image_samples_filenames(test_gen)
# Out:
# Filenames of images in the testing dataset:
# /Users/nirwanaamir/Downloads/dataset-2/Kasuami (Wakatobi)/38.png
# /Users/nirwanaamir/Downloads/dataset-2/Pa_piong (Toraja)/48.png
# /Users/nirwanaamir/Downloads/dataset-2/Kue Tetu(Sulawesi Barat)/34.jpg
# /Users/nirwanaamir/Downloads/dataset-2/klappertaart (Manado)/3.png
# /Users/nirwanaamir/Downloads/dataset-2/Barongko (Sulawesi Selatan)/38.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Konro (Makassar)/25.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Cakalang Pampis (Manado)/15.png
# /Users/nirwanaamir/Downloads/dataset-2/Kapurung (Palopo)/35.png
# /Users/nirwanaamir/Downloads/dataset-2/Konro (Makassar)/1.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Nasu Palekko (Pinrang)/34.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Lalampa(Sulawesi Tengah)/13.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Pisang Ijo (Makassar)/25.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Konro (Makassar)/36.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Lawa Bale (Palopo)/36.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Nasu Palekko (Pinrang)/9.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Nasu Palekko (Pinrang)/21.jpg
# /Users/nirwanaamir/Downloads/dataset-2/klappertaart (Manado)/36.png
# /Users/nirwanaamir/Downloads/dataset-2/Lapa-Lapa (Buton)/41.png
# /Users/nirwanaamir/Downloads/dataset-2/Konro (Makassar)/27.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Konro (Makassar)/6.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Lawa Bale (Palopo)/18.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Deppa Tori_ (Toraja)/50.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Barongko (Sulawesi Selatan)/45.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Barongko (Sulawesi Selatan)/12.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Barongko (Sulawesi Selatan)/41.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Lapa-Lapa (Buton)/10.png
# /Users/nirwanaamir/Downloads/dataset-2/klappertaart (Manado)/4.png
# /Users/nirwanaamir/Downloads/dataset-2/Lawa Bale (Palopo)/13.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Mie Titi(Makassar)/28.png
# /Users/nirwanaamir/Downloads/dataset-2/Barongko (Sulawesi Selatan)/37.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Kapurung (Palopo)/38.png
# /Users/nirwanaamir/Downloads/dataset-2/Kue Tetu(Sulawesi Barat)/31.jpeg
# /Users/nirwanaamir/Downloads/dataset-2/Ayam Woku (Manado)/42.png
# /Users/nirwanaamir/Downloads/dataset-2/Bubur Manado (Manado)/43.png
# /Users/nirwanaamir/Downloads/dataset-2/Panada (Sulawesi  Utara)/9.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Deppa Tori_ (Toraja)/19.jpg
# /Users/nirwanaamir/Downloads/dataset-2/klappertaart (Manado)/37.png
# /Users/nirwanaamir/Downloads/dataset-2/Pa_piong (Toraja)/5.png
# /Users/nirwanaamir/Downloads/dataset-2/Mie Titi(Makassar)/16.png
# /Users/nirwanaamir/Downloads/dataset-2/klappertaart (Manado)/42.png
# /Users/nirwanaamir/Downloads/dataset-2/Pisang Ijo (Makassar)/8.jpeg
# /Users/nirwanaamir/Downloads/dataset-2/Jagung Marning (Bulukumba)/9.png
# /Users/nirwanaamir/Downloads/dataset-2/Lalampa(Sulawesi Tengah)/8.jpg
# /Users/nirwanaamir/Downloads/dataset-2/klappertaart (Manado)/13.png
# /Users/nirwanaamir/Downloads/dataset-2/Jagung Marning (Bulukumba)/50.png
# /Users/nirwanaamir/Downloads/dataset-2/Coto Makassar (Makassar)/28.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Panada (Sulawesi  Utara)/17.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Konro (Makassar)/47.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Konro (Makassar)/16.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Lawa Bale (Palopo)/14.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Barongko (Sulawesi Selatan)/27.png
# /Users/nirwanaamir/Downloads/dataset-2/Coto Makassar (Makassar)/45.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Pa_piong (Toraja)/6.png
# /Users/nirwanaamir/Downloads/dataset-2/Kapurung (Palopo)/29.png
# /Users/nirwanaamir/Downloads/dataset-2/Barongko (Sulawesi Selatan)/36.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Lalampa(Sulawesi Tengah)/30.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Nasu Palekko (Pinrang)/44.jpeg
# /Users/nirwanaamir/Downloads/dataset-2/Panada (Sulawesi  Utara)/36.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Deppa Tori_ (Toraja)/33.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Deppa Tori_ (Toraja)/4.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Bubur Manado (Manado)/1.png
# /Users/nirwanaamir/Downloads/dataset-2/Barongko (Sulawesi Selatan)/4.jpg
# /Users/nirwanaamir/Downloads/dataset-2/klappertaart (Manado)/49.png
# /Users/nirwanaamir/Downloads/dataset-2/Lawa Bale (Palopo)/40.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Ayam Woku (Manado)/25.png
# /Users/nirwanaamir/Downloads/dataset-2/Kasuami (Wakatobi)/12.png
# /Users/nirwanaamir/Downloads/dataset-2/Coto Makassar (Makassar)/30.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Deppa Tori_ (Toraja)/32.jpeg
# /Users/nirwanaamir/Downloads/dataset-2/Nasu Palekko (Pinrang)/17.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Konro (Makassar)/29.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Kapurung (Palopo)/32.png
# /Users/nirwanaamir/Downloads/dataset-2/Pa_piong (Toraja)/32.png
# /Users/nirwanaamir/Downloads/dataset-2/Lalampa(Sulawesi Tengah)/27.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Kue Tetu(Sulawesi Barat)/50.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Kapurung (Palopo)/25.png
# /Users/nirwanaamir/Downloads/dataset-2/Kue Tetu(Sulawesi Barat)/4.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Kasuami (Wakatobi)/8.png
# /Users/nirwanaamir/Downloads/dataset-2/Coto Makassar (Makassar)/8.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Ayam Woku (Manado)/40.png
# /Users/nirwanaamir/Downloads/dataset-2/Kasuami (Wakatobi)/7.png
# /Users/nirwanaamir/Downloads/dataset-2/Deppa Tori_ (Toraja)/5.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Jagung Marning (Bulukumba)/20.png
# /Users/nirwanaamir/Downloads/dataset-2/Konro (Makassar)/44.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Mie Titi(Makassar)/14.png
# /Users/nirwanaamir/Downloads/dataset-2/Lalampa(Sulawesi Tengah)/12.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Lapa-Lapa (Buton)/25.png
# /Users/nirwanaamir/Downloads/dataset-2/Lalampa(Sulawesi Tengah)/24.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Kue Tetu(Sulawesi Barat)/6.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Kue Tetu(Sulawesi Barat)/43.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Pisang Ijo (Makassar)/20.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Barongko (Sulawesi Selatan)/2.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Nasu Palekko (Pinrang)/18.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Nasu Palekko (Pinrang)/43.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Kasuami (Wakatobi)/30.png
# /Users/nirwanaamir/Downloads/dataset-2/Ayam Woku (Manado)/47.png
# /Users/nirwanaamir/Downloads/dataset-2/Pisang Ijo (Makassar)/6.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Panada (Sulawesi  Utara)/26.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Pisang Ijo (Makassar)/12.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Barongko (Sulawesi Selatan)/47.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Pisang Ijo (Makassar)/49.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Jagung Marning (Bulukumba)/1.png
# /Users/nirwanaamir/Downloads/dataset-2/Bubur Manado (Manado)/36.png
# /Users/nirwanaamir/Downloads/dataset-2/Pisang Ijo (Makassar)/46.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Lawa Bale (Palopo)/3.jpeg
# /Users/nirwanaamir/Downloads/dataset-2/Coto Makassar (Makassar)/18.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Coto Makassar (Makassar)/16.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Pisang Ijo (Makassar)/15.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Nasu Palekko (Pinrang)/47.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Mie Titi(Makassar)/42.png
# /Users/nirwanaamir/Downloads/dataset-2/Lalampa(Sulawesi Tengah)/4.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Lalampa(Sulawesi Tengah)/3.jpeg
# /Users/nirwanaamir/Downloads/dataset-2/Pa_piong (Toraja)/12.png
# /Users/nirwanaamir/Downloads/dataset-2/Kue Tetu(Sulawesi Barat)/41.jpeg
# /Users/nirwanaamir/Downloads/dataset-2/Kasuami (Wakatobi)/1.png
# /Users/nirwanaamir/Downloads/dataset-2/klappertaart (Manado)/29.png
# /Users/nirwanaamir/Downloads/dataset-2/Jagung Marning (Bulukumba)/42.png
# /Users/nirwanaamir/Downloads/dataset-2/Panada (Sulawesi  Utara)/24.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Nasu Palekko (Pinrang)/24.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Konro (Makassar)/31.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Konro (Makassar)/43.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Pisang Ijo (Makassar)/14.jpg
# /Users/nirwanaamir/Downloads/dataset-2/klappertaart (Manado)/18.png
# /Users/nirwanaamir/Downloads/dataset-2/Barongko (Sulawesi Selatan)/18.jpeg
# /Users/nirwanaamir/Downloads/dataset-2/Mie Titi(Makassar)/1.png
# /Users/nirwanaamir/Downloads/dataset-2/Ayam Woku (Manado)/18.png
# /Users/nirwanaamir/Downloads/dataset-2/Jagung Marning (Bulukumba)/37.png
# /Users/nirwanaamir/Downloads/dataset-2/Cakalang Pampis (Manado)/11.png
# /Users/nirwanaamir/Downloads/dataset-2/Bubur Manado (Manado)/42.png
# /Users/nirwanaamir/Downloads/dataset-2/Kue Tetu(Sulawesi Barat)/28.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Lapa-Lapa (Buton)/48.png
# /Users/nirwanaamir/Downloads/dataset-2/Lalampa(Sulawesi Tengah)/23.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Jagung Marning (Bulukumba)/21.png
# /Users/nirwanaamir/Downloads/dataset-2/Nasu Palekko (Pinrang)/20.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Coto Makassar (Makassar)/17.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Deppa Tori_ (Toraja)/22.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Coto Makassar (Makassar)/42.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Lawa Bale (Palopo)/6.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Pa_piong (Toraja)/9.png
# /Users/nirwanaamir/Downloads/dataset-2/Mie Titi(Makassar)/6.png
# /Users/nirwanaamir/Downloads/dataset-2/Lalampa(Sulawesi Tengah)/33.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Pa_piong (Toraja)/16.png
# /Users/nirwanaamir/Downloads/dataset-2/Barongko (Sulawesi Selatan)/30.jpeg
# /Users/nirwanaamir/Downloads/dataset-2/Cakalang Pampis (Manado)/47.png
# /Users/nirwanaamir/Downloads/dataset-2/Jagung Marning (Bulukumba)/34.png
# /Users/nirwanaamir/Downloads/dataset-2/Kue Tetu(Sulawesi Barat)/7.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Jagung Marning (Bulukumba)/19.png
# /Users/nirwanaamir/Downloads/dataset-2/Lalampa(Sulawesi Tengah)/35.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Deppa Tori_ (Toraja)/42.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Deppa Tori_ (Toraja)/25.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Nasu Palekko (Pinrang)/12.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Ayam Woku (Manado)/14.png
# /Users/nirwanaamir/Downloads/dataset-2/Barongko (Sulawesi Selatan)/25.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Kue Tetu(Sulawesi Barat)/37.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Deppa Tori_ (Toraja)/18.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Konro (Makassar)/34.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Pa_piong (Toraja)/46.png
# /Users/nirwanaamir/Downloads/dataset-2/Mie Titi(Makassar)/3.png
# /Users/nirwanaamir/Downloads/dataset-2/Kue Tetu(Sulawesi Barat)/36.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Barongko (Sulawesi Selatan)/23.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Nasu Palekko (Pinrang)/3.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Lawa Bale (Palopo)/22.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Lapa-Lapa (Buton)/21.png
# /Users/nirwanaamir/Downloads/dataset-2/Jagung Marning (Bulukumba)/17.png
# /Users/nirwanaamir/Downloads/dataset-2/Kue Tetu(Sulawesi Barat)/3.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Pisang Ijo (Makassar)/43.jpg
# /Users/nirwanaamir/Downloads/dataset-2/klappertaart (Manado)/31.png
# /Users/nirwanaamir/Downloads/dataset-2/Bubur Manado (Manado)/29.png
# /Users/nirwanaamir/Downloads/dataset-2/klappertaart (Manado)/39.png
# /Users/nirwanaamir/Downloads/dataset-2/Jagung Marning (Bulukumba)/36.png
# /Users/nirwanaamir/Downloads/dataset-2/Lapa-Lapa (Buton)/9.png
# /Users/nirwanaamir/Downloads/dataset-2/Barongko (Sulawesi Selatan)/21.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Panada (Sulawesi  Utara)/29.png
# /Users/nirwanaamir/Downloads/dataset-2/Bubur Manado (Manado)/17.png
# /Users/nirwanaamir/Downloads/dataset-2/Bubur Manado (Manado)/46.png
# /Users/nirwanaamir/Downloads/dataset-2/Kasuami (Wakatobi)/46.png
# /Users/nirwanaamir/Downloads/dataset-2/Coto Makassar (Makassar)/15.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Kasuami (Wakatobi)/10.png
# /Users/nirwanaamir/Downloads/dataset-2/Bubur Manado (Manado)/6.png
# /Users/nirwanaamir/Downloads/dataset-2/Mie Titi(Makassar)/48.png
# /Users/nirwanaamir/Downloads/dataset-2/Jagung Marning (Bulukumba)/38.png
# /Users/nirwanaamir/Downloads/dataset-2/Bubur Manado (Manado)/4.png
# /Users/nirwanaamir/Downloads/dataset-2/Deppa Tori_ (Toraja)/10.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Panada (Sulawesi  Utara)/39.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Cakalang Pampis (Manado)/35.png
# /Users/nirwanaamir/Downloads/dataset-2/Panada (Sulawesi  Utara)/19.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Bubur Manado (Manado)/35.png
# /Users/nirwanaamir/Downloads/dataset-2/Lapa-Lapa (Buton)/1.png
# /Users/nirwanaamir/Downloads/dataset-2/Deppa Tori_ (Toraja)/49.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Pisang Ijo (Makassar)/40.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Kapurung (Palopo)/45.png
# /Users/nirwanaamir/Downloads/dataset-2/Coto Makassar (Makassar)/39.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Cakalang Pampis (Manado)/12.png
# /Users/nirwanaamir/Downloads/dataset-2/Konro (Makassar)/50.jpg
# /Users/nirwanaamir/Downloads/dataset-2/klappertaart (Manado)/21.png
# /Users/nirwanaamir/Downloads/dataset-2/Konro (Makassar)/20.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Pa_piong (Toraja)/45.png
# /Users/nirwanaamir/Downloads/dataset-2/Kapurung (Palopo)/1.png
# /Users/nirwanaamir/Downloads/dataset-2/Nasu Palekko (Pinrang)/22.jpg
# /Users/nirwanaamir/Downloads/dataset-2/Ayam Woku (Manado)/11.png
# /Users/nirwanaamir/Downloads/dataset-2/Coto Makassar (Makassar)/9.jpg

# %% [markdown]
# ### create the model

# %%
base_model=tf.keras.applications.Xception(include_top=False, weights="imagenet",input_tensor=Input(shape=(224,224,3)))

# %%
base_model.summary()
# Out:
# Model: "xception"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_2 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  block1_conv1 (Conv2D)       (None, 111, 111, 32)         864       ['input_2[0][0]']
#
#  block1_conv1_bn (BatchNorm  (None, 111, 111, 32)         128       ['block1_conv1[0][0]']
#  alization)
#
#  block1_conv1_act (Activati  (None, 111, 111, 32)         0         ['block1_conv1_bn[0][0]']
#  on)
#
#  block1_conv2 (Conv2D)       (None, 109, 109, 64)         18432     ['block1_conv1_act[0][0]']
#
#  block1_conv2_bn (BatchNorm  (None, 109, 109, 64)         256       ['block1_conv2[0][0]']
#  alization)
#
#  block1_conv2_act (Activati  (None, 109, 109, 64)         0         ['block1_conv2_bn[0][0]']
#  on)
#
#  block2_sepconv1 (Separable  (None, 109, 109, 128)        8768      ['block1_conv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv1_bn (BatchN  (None, 109, 109, 128)        512       ['block2_sepconv1[0][0]']
#  ormalization)
#
#  block2_sepconv2_act (Activ  (None, 109, 109, 128)        0         ['block2_sepconv1_bn[0][0]']
#  ation)
#
#  block2_sepconv2 (Separable  (None, 109, 109, 128)        17536     ['block2_sepconv2_act[0][0]']
#  Conv2D)
#
#  block2_sepconv2_bn (BatchN  (None, 109, 109, 128)        512       ['block2_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_4 (Conv2D)           (None, 55, 55, 128)          8192      ['block1_conv2_act[0][0]']
#
#  block2_pool (MaxPooling2D)  (None, 55, 55, 128)          0         ['block2_sepconv2_bn[0][0]']
#
#  batch_normalization_4 (Bat  (None, 55, 55, 128)          512       ['conv2d_4[0][0]']
#  chNormalization)
#
#  add_12 (Add)                (None, 55, 55, 128)          0         ['block2_pool[0][0]',
#                                                                      'batch_normalization_4[0][0]'
#                                                                     ]
#
#  block3_sepconv1_act (Activ  (None, 55, 55, 128)          0         ['add_12[0][0]']
#  ation)
#
#  block3_sepconv1 (Separable  (None, 55, 55, 256)          33920     ['block3_sepconv1_act[0][0]']
#  Conv2D)
#
#  block3_sepconv1_bn (BatchN  (None, 55, 55, 256)          1024      ['block3_sepconv1[0][0]']
#  ormalization)
#
#  block3_sepconv2_act (Activ  (None, 55, 55, 256)          0         ['block3_sepconv1_bn[0][0]']
#  ation)
#
#  block3_sepconv2 (Separable  (None, 55, 55, 256)          67840     ['block3_sepconv2_act[0][0]']
#  Conv2D)
#
#  block3_sepconv2_bn (BatchN  (None, 55, 55, 256)          1024      ['block3_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_5 (Conv2D)           (None, 28, 28, 256)          32768     ['add_12[0][0]']
#
#  block3_pool (MaxPooling2D)  (None, 28, 28, 256)          0         ['block3_sepconv2_bn[0][0]']
#
#  batch_normalization_5 (Bat  (None, 28, 28, 256)          1024      ['conv2d_5[0][0]']
#  chNormalization)
#
#  add_13 (Add)                (None, 28, 28, 256)          0         ['block3_pool[0][0]',
#                                                                      'batch_normalization_5[0][0]'
#                                                                     ]
#
#  block4_sepconv1_act (Activ  (None, 28, 28, 256)          0         ['add_13[0][0]']
#  ation)
#
#  block4_sepconv1 (Separable  (None, 28, 28, 728)          188672    ['block4_sepconv1_act[0][0]']
#  Conv2D)
#
#  block4_sepconv1_bn (BatchN  (None, 28, 28, 728)          2912      ['block4_sepconv1[0][0]']
#  ormalization)
#
#  block4_sepconv2_act (Activ  (None, 28, 28, 728)          0         ['block4_sepconv1_bn[0][0]']
#  ation)
#
#  block4_sepconv2 (Separable  (None, 28, 28, 728)          536536    ['block4_sepconv2_act[0][0]']
#  Conv2D)
#
#  block4_sepconv2_bn (BatchN  (None, 28, 28, 728)          2912      ['block4_sepconv2[0][0]']
#  ormalization)
#
#  conv2d_6 (Conv2D)           (None, 14, 14, 728)          186368    ['add_13[0][0]']
#
#  block4_pool (MaxPooling2D)  (None, 14, 14, 728)          0         ['block4_sepconv2_bn[0][0]']
#
#  batch_normalization_6 (Bat  (None, 14, 14, 728)          2912      ['conv2d_6[0][0]']
#  chNormalization)
#
#  add_14 (Add)                (None, 14, 14, 728)          0         ['block4_pool[0][0]',
#                                                                      'batch_normalization_6[0][0]'
#                                                                     ]
#
#  block5_sepconv1_act (Activ  (None, 14, 14, 728)          0         ['add_14[0][0]']
#  ation)
#
#  block5_sepconv1 (Separable  (None, 14, 14, 728)          536536    ['block5_sepconv1_act[0][0]']
#  Conv2D)
#
#  block5_sepconv1_bn (BatchN  (None, 14, 14, 728)          2912      ['block5_sepconv1[0][0]']
#  ormalization)
#
#  block5_sepconv2_act (Activ  (None, 14, 14, 728)          0         ['block5_sepconv1_bn[0][0]']
#  ation)
#
#  block5_sepconv2 (Separable  (None, 14, 14, 728)          536536    ['block5_sepconv2_act[0][0]']
#  Conv2D)
#
#  block5_sepconv2_bn (BatchN  (None, 14, 14, 728)          2912      ['block5_sepconv2[0][0]']
#  ormalization)
#
#  block5_sepconv3_act (Activ  (None, 14, 14, 728)          0         ['block5_sepconv2_bn[0][0]']
#  ation)
#
#  block5_sepconv3 (Separable  (None, 14, 14, 728)          536536    ['block5_sepconv3_act[0][0]']
#  Conv2D)
#
#  block5_sepconv3_bn (BatchN  (None, 14, 14, 728)          2912      ['block5_sepconv3[0][0]']
#  ormalization)
#
#  add_15 (Add)                (None, 14, 14, 728)          0         ['block5_sepconv3_bn[0][0]',
#                                                                      'add_14[0][0]']
#
#  block6_sepconv1_act (Activ  (None, 14, 14, 728)          0         ['add_15[0][0]']
#  ation)
#
#  block6_sepconv1 (Separable  (None, 14, 14, 728)          536536    ['block6_sepconv1_act[0][0]']
#  Conv2D)
#
#  block6_sepconv1_bn (BatchN  (None, 14, 14, 728)          2912      ['block6_sepconv1[0][0]']
#  ormalization)
#
#  block6_sepconv2_act (Activ  (None, 14, 14, 728)          0         ['block6_sepconv1_bn[0][0]']
#  ation)
#
#  block6_sepconv2 (Separable  (None, 14, 14, 728)          536536    ['block6_sepconv2_act[0][0]']
#  Conv2D)
#
#  block6_sepconv2_bn (BatchN  (None, 14, 14, 728)          2912      ['block6_sepconv2[0][0]']
#  ormalization)
#
#  block6_sepconv3_act (Activ  (None, 14, 14, 728)          0         ['block6_sepconv2_bn[0][0]']
#  ation)
#
#  block6_sepconv3 (Separable  (None, 14, 14, 728)          536536    ['block6_sepconv3_act[0][0]']
#  Conv2D)
#
#  block6_sepconv3_bn (BatchN  (None, 14, 14, 728)          2912      ['block6_sepconv3[0][0]']
#  ormalization)
#
#  add_16 (Add)                (None, 14, 14, 728)          0         ['block6_sepconv3_bn[0][0]',
#                                                                      'add_15[0][0]']
#
#  block7_sepconv1_act (Activ  (None, 14, 14, 728)          0         ['add_16[0][0]']
#  ation)
#
#  block7_sepconv1 (Separable  (None, 14, 14, 728)          536536    ['block7_sepconv1_act[0][0]']
#  Conv2D)
#
#  block7_sepconv1_bn (BatchN  (None, 14, 14, 728)          2912      ['block7_sepconv1[0][0]']
#  ormalization)
#
#  block7_sepconv2_act (Activ  (None, 14, 14, 728)          0         ['block7_sepconv1_bn[0][0]']
#  ation)
#
#  block7_sepconv2 (Separable  (None, 14, 14, 728)          536536    ['block7_sepconv2_act[0][0]']
#  Conv2D)
#
#  block7_sepconv2_bn (BatchN  (None, 14, 14, 728)          2912      ['block7_sepconv2[0][0]']
#  ormalization)
#
#  block7_sepconv3_act (Activ  (None, 14, 14, 728)          0         ['block7_sepconv2_bn[0][0]']
#  ation)
#
#  block7_sepconv3 (Separable  (None, 14, 14, 728)          536536    ['block7_sepconv3_act[0][0]']
#  Conv2D)
#
#  block7_sepconv3_bn (BatchN  (None, 14, 14, 728)          2912      ['block7_sepconv3[0][0]']
#  ormalization)
#
#  add_17 (Add)                (None, 14, 14, 728)          0         ['block7_sepconv3_bn[0][0]',
#                                                                      'add_16[0][0]']
#
#  block8_sepconv1_act (Activ  (None, 14, 14, 728)          0         ['add_17[0][0]']
#  ation)
#
#  block8_sepconv1 (Separable  (None, 14, 14, 728)          536536    ['block8_sepconv1_act[0][0]']
#  Conv2D)
#
#  block8_sepconv1_bn (BatchN  (None, 14, 14, 728)          2912      ['block8_sepconv1[0][0]']
#  ormalization)
#
#  block8_sepconv2_act (Activ  (None, 14, 14, 728)          0         ['block8_sepconv1_bn[0][0]']
#  ation)
#
#  block8_sepconv2 (Separable  (None, 14, 14, 728)          536536    ['block8_sepconv2_act[0][0]']
#  Conv2D)
#
#  block8_sepconv2_bn (BatchN  (None, 14, 14, 728)          2912      ['block8_sepconv2[0][0]']
#  ormalization)
#
#  block8_sepconv3_act (Activ  (None, 14, 14, 728)          0         ['block8_sepconv2_bn[0][0]']
#  ation)
#
#  block8_sepconv3 (Separable  (None, 14, 14, 728)          536536    ['block8_sepconv3_act[0][0]']
#  Conv2D)
#
#  block8_sepconv3_bn (BatchN  (None, 14, 14, 728)          2912      ['block8_sepconv3[0][0]']
#  ormalization)
#
#  add_18 (Add)                (None, 14, 14, 728)          0         ['block8_sepconv3_bn[0][0]',
#                                                                      'add_17[0][0]']
#
#  block9_sepconv1_act (Activ  (None, 14, 14, 728)          0         ['add_18[0][0]']
#  ation)
#
#  block9_sepconv1 (Separable  (None, 14, 14, 728)          536536    ['block9_sepconv1_act[0][0]']
#  Conv2D)
#
#  block9_sepconv1_bn (BatchN  (None, 14, 14, 728)          2912      ['block9_sepconv1[0][0]']
#  ormalization)
#
#  block9_sepconv2_act (Activ  (None, 14, 14, 728)          0         ['block9_sepconv1_bn[0][0]']
#  ation)
#
#  block9_sepconv2 (Separable  (None, 14, 14, 728)          536536    ['block9_sepconv2_act[0][0]']
#  Conv2D)
#
#  block9_sepconv2_bn (BatchN  (None, 14, 14, 728)          2912      ['block9_sepconv2[0][0]']
#  ormalization)
#
#  block9_sepconv3_act (Activ  (None, 14, 14, 728)          0         ['block9_sepconv2_bn[0][0]']
#  ation)
#
#  block9_sepconv3 (Separable  (None, 14, 14, 728)          536536    ['block9_sepconv3_act[0][0]']
#  Conv2D)
#
#  block9_sepconv3_bn (BatchN  (None, 14, 14, 728)          2912      ['block9_sepconv3[0][0]']
#  ormalization)
#
#  add_19 (Add)                (None, 14, 14, 728)          0         ['block9_sepconv3_bn[0][0]',
#                                                                      'add_18[0][0]']
#
#  block10_sepconv1_act (Acti  (None, 14, 14, 728)          0         ['add_19[0][0]']
#  vation)
#
#  block10_sepconv1 (Separabl  (None, 14, 14, 728)          536536    ['block10_sepconv1_act[0][0]']
#  eConv2D)
#
#  block10_sepconv1_bn (Batch  (None, 14, 14, 728)          2912      ['block10_sepconv1[0][0]']
#  Normalization)
#
#  block10_sepconv2_act (Acti  (None, 14, 14, 728)          0         ['block10_sepconv1_bn[0][0]']
#  vation)
#
#  block10_sepconv2 (Separabl  (None, 14, 14, 728)          536536    ['block10_sepconv2_act[0][0]']
#  eConv2D)
#
#  block10_sepconv2_bn (Batch  (None, 14, 14, 728)          2912      ['block10_sepconv2[0][0]']
#  Normalization)
#
#  block10_sepconv3_act (Acti  (None, 14, 14, 728)          0         ['block10_sepconv2_bn[0][0]']
#  vation)
#
#  block10_sepconv3 (Separabl  (None, 14, 14, 728)          536536    ['block10_sepconv3_act[0][0]']
#  eConv2D)
#
#  block10_sepconv3_bn (Batch  (None, 14, 14, 728)          2912      ['block10_sepconv3[0][0]']
#  Normalization)
#
#  add_20 (Add)                (None, 14, 14, 728)          0         ['block10_sepconv3_bn[0][0]',
#                                                                      'add_19[0][0]']
#
#  block11_sepconv1_act (Acti  (None, 14, 14, 728)          0         ['add_20[0][0]']
#  vation)
#
#  block11_sepconv1 (Separabl  (None, 14, 14, 728)          536536    ['block11_sepconv1_act[0][0]']
#  eConv2D)
#
#  block11_sepconv1_bn (Batch  (None, 14, 14, 728)          2912      ['block11_sepconv1[0][0]']
#  Normalization)
#
#  block11_sepconv2_act (Acti  (None, 14, 14, 728)          0         ['block11_sepconv1_bn[0][0]']
#  vation)
#
#  block11_sepconv2 (Separabl  (None, 14, 14, 728)          536536    ['block11_sepconv2_act[0][0]']
#  eConv2D)
#
#  block11_sepconv2_bn (Batch  (None, 14, 14, 728)          2912      ['block11_sepconv2[0][0]']
#  Normalization)
#
#  block11_sepconv3_act (Acti  (None, 14, 14, 728)          0         ['block11_sepconv2_bn[0][0]']
#  vation)
#
#  block11_sepconv3 (Separabl  (None, 14, 14, 728)          536536    ['block11_sepconv3_act[0][0]']
#  eConv2D)
#
#  block11_sepconv3_bn (Batch  (None, 14, 14, 728)          2912      ['block11_sepconv3[0][0]']
#  Normalization)
#
#  add_21 (Add)                (None, 14, 14, 728)          0         ['block11_sepconv3_bn[0][0]',
#                                                                      'add_20[0][0]']
#
#  block12_sepconv1_act (Acti  (None, 14, 14, 728)          0         ['add_21[0][0]']
#  vation)
#
#  block12_sepconv1 (Separabl  (None, 14, 14, 728)          536536    ['block12_sepconv1_act[0][0]']
#  eConv2D)
#
#  block12_sepconv1_bn (Batch  (None, 14, 14, 728)          2912      ['block12_sepconv1[0][0]']
#  Normalization)
#
#  block12_sepconv2_act (Acti  (None, 14, 14, 728)          0         ['block12_sepconv1_bn[0][0]']
#  vation)
#
#  block12_sepconv2 (Separabl  (None, 14, 14, 728)          536536    ['block12_sepconv2_act[0][0]']
#  eConv2D)
#
#  block12_sepconv2_bn (Batch  (None, 14, 14, 728)          2912      ['block12_sepconv2[0][0]']
#  Normalization)
#
#  block12_sepconv3_act (Acti  (None, 14, 14, 728)          0         ['block12_sepconv2_bn[0][0]']
#  vation)
#
#  block12_sepconv3 (Separabl  (None, 14, 14, 728)          536536    ['block12_sepconv3_act[0][0]']
#  eConv2D)
#
#  block12_sepconv3_bn (Batch  (None, 14, 14, 728)          2912      ['block12_sepconv3[0][0]']
#  Normalization)
#
#  add_22 (Add)                (None, 14, 14, 728)          0         ['block12_sepconv3_bn[0][0]',
#                                                                      'add_21[0][0]']
#
#  block13_sepconv1_act (Acti  (None, 14, 14, 728)          0         ['add_22[0][0]']
#  vation)
#
#  block13_sepconv1 (Separabl  (None, 14, 14, 728)          536536    ['block13_sepconv1_act[0][0]']
#  eConv2D)
#
#  block13_sepconv1_bn (Batch  (None, 14, 14, 728)          2912      ['block13_sepconv1[0][0]']
#  Normalization)
#
#  block13_sepconv2_act (Acti  (None, 14, 14, 728)          0         ['block13_sepconv1_bn[0][0]']
#  vation)
#
#  block13_sepconv2 (Separabl  (None, 14, 14, 1024)         752024    ['block13_sepconv2_act[0][0]']
#  eConv2D)
#
#  block13_sepconv2_bn (Batch  (None, 14, 14, 1024)         4096      ['block13_sepconv2[0][0]']
#  Normalization)
#
#  conv2d_7 (Conv2D)           (None, 7, 7, 1024)           745472    ['add_22[0][0]']
#
#  block13_pool (MaxPooling2D  (None, 7, 7, 1024)           0         ['block13_sepconv2_bn[0][0]']
#  )
#
#  batch_normalization_7 (Bat  (None, 7, 7, 1024)           4096      ['conv2d_7[0][0]']
#  chNormalization)
#
#  add_23 (Add)                (None, 7, 7, 1024)           0         ['block13_pool[0][0]',
#                                                                      'batch_normalization_7[0][0]'
#                                                                     ]
#
#  block14_sepconv1 (Separabl  (None, 7, 7, 1536)           1582080   ['add_23[0][0]']
#  eConv2D)
#
#  block14_sepconv1_bn (Batch  (None, 7, 7, 1536)           6144      ['block14_sepconv1[0][0]']
#  Normalization)
#
#  block14_sepconv1_act (Acti  (None, 7, 7, 1536)           0         ['block14_sepconv1_bn[0][0]']
#  vation)
#
#  block14_sepconv2 (Separabl  (None, 7, 7, 2048)           3159552   ['block14_sepconv1_act[0][0]']
#  eConv2D)
#
#  block14_sepconv2_bn (Batch  (None, 7, 7, 2048)           8192      ['block14_sepconv2[0][0]']
#  Normalization)
#
#  block14_sepconv2_act (Acti  (None, 7, 7, 2048)           0         ['block14_sepconv2_bn[0][0]']
#  vation)
#
# ==================================================================================================
# Total params: 20861480 (79.58 MB)
# Trainable params: 20806952 (79.37 MB)
# Non-trainable params: 54528 (213.00 KB)
# __________________________________________________________________________________________________

# %%
base_model.trainable = False

# %%
model_name='Cendekia'
print("Building model with", base_model)
model = tf.keras.Sequential([
            # Note the input shape is the desired size of the image 128x128 with 3 bytes color
            # This is the first convolution
            base_model,
            tf.keras.layers.MaxPool2D(pool_size=2, strides=2),
            tf.keras.layers.Dropout(rate=0.5),

            tf.keras.layers.Flatten(),
            tf.keras.layers.Dense(20, activation='softmax')
])

model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=.001), loss='categorical_crossentropy', metrics='accuracy')
# Out:
# WARNING:absl:At this time, the v2.11+ optimizer `tf.keras.optimizers.Adam` runs slowly on M1/M2 Macs, please use the legacy Keras optimizer instead, located at `tf.keras.optimizers.legacy.Adam`.
# Building model with <keras.src.engine.functional.Functional object at 0x290cfef10>

# %%
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  xception (Functional)       (None, 7, 7, 2048)        20861480
#
#  max_pooling2d_1 (MaxPoolin  (None, 3, 3, 2048)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 3, 3, 2048)        0
#
#  flatten_1 (Flatten)         (None, 18432)             0
#
#  dense_1 (Dense)             (None, 20)                368660
#
# =================================================================
# Total params: 21230140 (80.99 MB)
# Trainable params: 368660 (1.41 MB)
# Non-trainable params: 20861480 (79.58 MB)
# _________________________________________________________________

# %%
epochs = 50

history=model.fit(x=train_gen, epochs=epochs, validation_data=valid_gen)
# Out:
# Epoch 1/50
# 11/11 [==============================] - 138s 12s/step - loss: 3.1502 - accuracy: 0.3414 - val_loss: 1.4353 - val_accuracy: 0.6100
# Epoch 2/50
# 11/11 [==============================] - 173s 16s/step - loss: 1.0144 - accuracy: 0.7400 - val_loss: 0.7676 - val_accuracy: 0.7500
# Epoch 3/50
# 11/11 [==============================] - 168s 15s/step - loss: 0.6046 - accuracy: 0.8357 - val_loss: 0.6476 - val_accuracy: 0.8400
# Epoch 4/50
# 11/11 [==============================] - 158s 14s/step - loss: 0.3767 - accuracy: 0.8729 - val_loss: 0.5899 - val_accuracy: 0.8800
# Epoch 5/50
# 11/11 [==============================] - 147s 13s/step - loss: 0.2392 - accuracy: 0.9157 - val_loss: 0.4842 - val_accuracy: 0.8600
# Epoch 6/50
# 11/11 [==============================] - 173s 15s/step - loss: 0.1843 - accuracy: 0.9300 - val_loss: 0.5534 - val_accuracy: 0.8500
# Epoch 7/50
# 11/11 [==============================] - 151s 14s/step - loss: 0.1519 - accuracy: 0.9414 - val_loss: 0.5870 - val_accuracy: 0.8500
# Epoch 8/50
# 11/11 [==============================] - 193s 17s/step - loss: 0.1355 - accuracy: 0.9543 - val_loss: 0.4725 - val_accuracy: 0.8400
# Epoch 9/50
# 11/11 [==============================] - 180s 16s/step - loss: 0.1116 - accuracy: 0.9600 - val_loss: 0.4868 - val_accuracy: 0.8900
# Epoch 10/50
# 11/11 [==============================] - 170s 15s/step - loss: 0.1005 - accuracy: 0.9700 - val_loss: 0.4711 - val_accuracy: 0.8900
# Epoch 11/50
# 11/11 [==============================] - 173s 15s/step - loss: 0.1029 - accuracy: 0.9671 - val_loss: 0.4427 - val_accuracy: 0.8600
# Epoch 12/50
# 11/11 [==============================] - 182s 16s/step - loss: 0.0977 - accuracy: 0.9700 - val_loss: 0.5331 - val_accuracy: 0.8800
# Epoch 13/50
# 11/11 [==============================] - 166s 12s/step - loss: 0.1472 - accuracy: 0.9457 - val_loss: 0.5374 - val_accuracy: 0.8700
# Epoch 14/50
# 11/11 [==============================] - 168s 15s/step - loss: 0.1366 - accuracy: 0.9571 - val_loss: 0.6331 - val_accuracy: 0.8600
# Epoch 15/50
# 11/11 [==============================] - 194s 17s/step - loss: 0.0791 - accuracy: 0.9700 - val_loss: 0.4561 - val_accuracy: 0.8800
# Epoch 16/50
# 11/11 [==============================] - 200s 18s/step - loss: 0.0774 - accuracy: 0.9757 - val_loss: 0.5415 - val_accuracy: 0.8600
# Epoch 17/50
# 11/11 [==============================] - 286s 26s/step - loss: 0.0974 - accuracy: 0.9614 - val_loss: 0.6309 - val_accuracy: 0.8200
# Epoch 18/50
# 11/11 [==============================] - 135s 12s/step - loss: 0.0805 - accuracy: 0.9671 - val_loss: 0.6626 - val_accuracy: 0.8800
# Epoch 19/50
# 11/11 [==============================] - 165s 15s/step - loss: 0.0910 - accuracy: 0.9700 - val_loss: 0.6034 - val_accuracy: 0.8800
# Epoch 20/50
# 11/11 [==============================] - 186s 17s/step - loss: 0.0645 - accuracy: 0.9743 - val_loss: 0.7471 - val_accuracy: 0.8500
# Epoch 21/50
# 11/11 [==============================] - 198s 18s/step - loss: 0.0686 - accuracy: 0.9757 - val_loss: 0.5879 - val_accuracy: 0.8400
# Epoch 22/50
# 11/11 [==============================] - 202s 18s/step - loss: 0.0652 - accuracy: 0.9700 - val_loss: 0.6281 - val_accuracy: 0.8900
# Epoch 23/50
# 11/11 [==============================] - 206s 18s/step - loss: 0.0584 - accuracy: 0.9843 - val_loss: 0.7472 - val_accuracy: 0.8700
# Epoch 24/50
# 11/11 [==============================] - 204s 18s/step - loss: 0.0342 - accuracy: 0.9900 - val_loss: 0.5751 - val_accuracy: 0.8700
# Epoch 25/50
# 11/11 [==============================] - 202s 18s/step - loss: 0.0467 - accuracy: 0.9843 - val_loss: 0.7322 - val_accuracy: 0.8700
# Epoch 26/50
# 11/11 [==============================] - 200s 18s/step - loss: 0.0724 - accuracy: 0.9729 - val_loss: 0.7369 - val_accuracy: 0.8200
# Epoch 27/50
# 11/11 [==============================] - 200s 18s/step - loss: 0.0782 - accuracy: 0.9757 - val_loss: 0.6399 - val_accuracy: 0.8500
# Epoch 28/50
# 11/11 [==============================] - 198s 17s/step - loss: 0.0564 - accuracy: 0.9800 - val_loss: 0.6624 - val_accuracy: 0.8600
# Epoch 29/50
# 11/11 [==============================] - 202s 18s/step - loss: 0.0492 - accuracy: 0.9814 - val_loss: 0.7703 - val_accuracy: 0.8700
# Epoch 30/50
# 11/11 [==============================] - 206s 18s/step - loss: 0.0865 - accuracy: 0.9729 - val_loss: 0.8036 - val_accuracy: 0.8200
# Epoch 31/50
# 11/11 [==============================] - 195s 17s/step - loss: 0.0857 - accuracy: 0.9714 - val_loss: 0.6580 - val_accuracy: 0.8600
# Epoch 32/50
# 11/11 [==============================] - 194s 17s/step - loss: 0.0694 - accuracy: 0.9786 - val_loss: 0.7358 - val_accuracy: 0.8500
# Epoch 33/50
# 11/11 [==============================] - 190s 17s/step - loss: 0.0669 - accuracy: 0.9786 - val_loss: 0.7043 - val_accuracy: 0.8600
# Epoch 34/50
# 11/11 [==============================] - 195s 17s/step - loss: 0.0666 - accuracy: 0.9786 - val_loss: 0.9388 - val_accuracy: 0.8500
# Epoch 35/50
# 11/11 [==============================] - 191s 17s/step - loss: 0.0870 - accuracy: 0.9657 - val_loss: 0.8802 - val_accuracy: 0.8300
# Epoch 36/50
# 11/11 [==============================] - 192s 17s/step - loss: 0.0514 - accuracy: 0.9814 - val_loss: 0.7911 - val_accuracy: 0.8600
# Epoch 37/50
# 11/11 [==============================] - 1026s 100s/step - loss: 0.0547 - accuracy: 0.9800 - val_loss: 0.7610 - val_accuracy: 0.9000
# Epoch 38/50
# 11/11 [==============================] - 138s 12s/step - loss: 0.0880 - accuracy: 0.9714 - val_loss: 0.9890 - val_accuracy: 0.8400
# Epoch 39/50
# 11/11 [==============================] - 146s 13s/step - loss: 0.0612 - accuracy: 0.9829 - val_loss: 0.6625 - val_accuracy: 0.8600
# Epoch 40/50
# 11/11 [==============================] - 205s 18s/step - loss: 0.0703 - accuracy: 0.9757 - val_loss: 0.9341 - val_accuracy: 0.8400
# Epoch 41/50
# 11/11 [==============================] - 278s 25s/step - loss: 0.0514 - accuracy: 0.9729 - val_loss: 0.9200 - val_accuracy: 0.8200
# Epoch 42/50
# 11/11 [==============================] - 349s 31s/step - loss: 0.0428 - accuracy: 0.9857 - val_loss: 1.0411 - val_accuracy: 0.8300
# Epoch 43/50
# 11/11 [==============================] - 342s 30s/step - loss: 0.0327 - accuracy: 0.9886 - val_loss: 0.7863 - val_accuracy: 0.8700
# Epoch 44/50
# 11/11 [==============================] - 312s 27s/step - loss: 0.0306 - accuracy: 0.9886 - val_loss: 1.0006 - val_accuracy: 0.8400
# Epoch 45/50
# 11/11 [==============================] - 206s 18s/step - loss: 0.0529 - accuracy: 0.9857 - val_loss: 0.9136 - val_accuracy: 0.8400
# Epoch 46/50
# 11/11 [==============================] - 201s 18s/step - loss: 0.0297 - accuracy: 0.9900 - val_loss: 0.9249 - val_accuracy: 0.8300
# Epoch 47/50
# 11/11 [==============================] - 199s 18s/step - loss: 0.0432 - accuracy: 0.9843 - val_loss: 0.7779 - val_accuracy: 0.8800
# Epoch 48/50
# 11/11 [==============================] - 259s 24s/step - loss: 0.0303 - accuracy: 0.9886 - val_loss: 0.9035 - val_accuracy: 0.8700
# Epoch 49/50
# 11/11 [==============================] - 146s 13s/step - loss: 0.0432 - accuracy: 0.9886 - val_loss: 0.8600 - val_accuracy: 0.8600
# Epoch 50/50
# 11/11 [==============================] - 172s 15s/step - loss: 0.0571 - accuracy: 0.9829 - val_loss: 1.0007 - val_accuracy: 0.8700

# %% [markdown]
# ### define function to print text in RGB foreground and background colors

# %%
def print_in_color(txt_msg, fore_tupple, back_tupple):
    # prints the text_msg in the foreground color specified by fore_tupple with the background specified by back_tupple
    # text_msg is the text, fore_tupple is foregroud color tuple (r, g, b), back_tupple is background tuple (r, g, b)
    rf, gf, bf = fore_tupple
    rb, gb, bb = back_tupple
    msg = '{0}' + txt_msg
    mat = '\33[38;2;' + str(rf) + ';' + str(gf) + ';' + str(bf) + ';48;2;' + str(rb) + ';' + str(gb) + ';' + str(
        bb) + 'm'
    print(msg.format(mat), flush=True)
    print('\33[0m', flush=True)  # returns default print color to back to black
    return

# %% [markdown]
# ### define function to plot the training data

# %%
def tr_plot(tr_data, start_epoch):
    #Plot the training and validation data
    tacc=tr_data.history['accuracy']
    tloss=tr_data.history['loss']
    vacc=tr_data.history['val_accuracy']
    vloss=tr_data.history['val_loss']
    Epoch_count=len(tacc)+ start_epoch
    Epochs=[]
    for i in range (start_epoch ,Epoch_count):
        Epochs.append(i+1)   
    index_loss=np.argmin(vloss)#  this is the epoch with the lowest validation loss
    val_lowest=vloss[index_loss]
    index_acc=np.argmax(vacc)
    acc_highest=vacc[index_acc]
    plt.style.use('fivethirtyeight')
    sc_label='best epoch= '+ str(index_loss+1 +start_epoch)
    vc_label='best epoch= '+ str(index_acc + 1+ start_epoch)
    fig,axes=plt.subplots(nrows=1, ncols=2, figsize=(20,8))
    axes[0].plot(Epochs,tloss, 'r', label='Training loss')
    axes[0].plot(Epochs,vloss,'g',label='Validation loss' )
    axes[0].scatter(index_loss+1 +start_epoch,val_lowest, s=150, c= 'blue', label=sc_label)
    axes[0].set_title('Training and Validation Loss')
    axes[0].set_xlabel('Epochs')
    axes[0].set_ylabel('Loss')
    axes[0].legend()
    axes[1].plot (Epochs,tacc,'r',label= 'Training Accuracy')
    axes[1].plot (Epochs,vacc,'g',label= 'Validation Accuracy')
    axes[1].scatter(index_acc+1 +start_epoch,acc_highest, s=150, c= 'blue', label=vc_label)
    axes[1].set_title('Training and Validation Accuracy')
    axes[1].set_xlabel('Epochs')
    axes[1].set_ylabel('Accuracy')
    axes[1].legend()
    plt.tight_layout
    #plt.style.use('fivethirtyeight')
    plt.show()

# %% [markdown]
# ### define function to generate the confusion matrix and classification report

# %%
def print_info( test_gen, preds, print_code, save_dir, subject ):
    class_dict=test_gen.class_indices
    labels= test_gen.labels
    file_names= test_gen.filenames 
    error_list=[]
    true_class=[]
    pred_class=[]
    prob_list=[]
    new_dict={}
    error_indices=[]
    y_pred=[]
    for key,value in class_dict.items():
        new_dict[value]=key             # dictionary {integer of class number: string of class name}
    # store new_dict as a text fine in the save_dir
    classes=list(new_dict.values())     # list of string of class names
    dict_as_text=str(new_dict)
    dict_name= subject + '-' +str(len(classes)) +'.txt'  
    dict_path=os.path.join(save_dir,dict_name)    
    with open(dict_path, 'w') as x_file:
        x_file.write(dict_as_text)    
    errors=0      
    for i, p in enumerate(preds):
        pred_index=np.argmax(p)        
        true_index=labels[i]  # labels are integer values
        if pred_index != true_index: # a misclassification has occurred
            error_list.append(file_names[i])
            true_class.append(new_dict[true_index])
            pred_class.append(new_dict[pred_index])
            prob_list.append(p[pred_index])
            error_indices.append(true_index)            
            errors=errors + 1
        y_pred.append(pred_index)    
    if print_code !=0:
        if errors>0:
            if print_code>errors:
                r=errors
            else:
                r=print_code           
            msg='{0:^28s}{1:^28s}{2:^28s}{3:^16s}'.format('Filename', 'Predicted Class' , 'True Class', 'Probability')
            print_in_color(msg, (0,255,0),(55,65,80))
            for i in range(r):                
                split1=os.path.split(error_list[i])                
                split2=os.path.split(split1[0])                
                fname=split2[1] + '/' + split1[1]
                msg='{0:^28s}{1:^28s}{2:^28s}{3:4s}{4:^6.4f}'.format(fname, pred_class[i],true_class[i], ' ', prob_list[i])
                print_in_color(msg, (255,255,255), (55,65,60))
                #print(error_list[i]  , pred_class[i], true_class[i], prob_list[i])               
        else:
            msg='With accuracy of 100 % there are no errors to print'
            print_in_color(msg, (0,255,0),(55,65,80))
    if errors>0:
        plot_bar=[]
        plot_class=[]
        for  key, value in new_dict.items():        
            count=error_indices.count(key) 
            if count!=0:
                plot_bar.append(count) # list containg how many times a class c had an error
                plot_class.append(value)   # stores the class 
        fig=plt.figure()
        fig.set_figheight(len(plot_class)/3)
        fig.set_figwidth(10)
        plt.style.use('fivethirtyeight')
        for i in range(0, len(plot_class)):
            c=plot_class[i]
            x=plot_bar[i]
            plt.barh(c, x, )
            plt.title( ' Errors by Class on Test Set')
    y_true= np.array(labels)        
    y_pred=np.array(y_pred)
    if len(classes)<= 30:
        # create a confusion matrix 
        cm = confusion_matrix(y_true, y_pred )        
        length=len(classes)
        if length<8:
            fig_width=8
            fig_height=8
        else:
            fig_width= int(length * .5)
            fig_height= int(length * .5)
        plt.figure(figsize=(fig_width, fig_height))
        sns.heatmap(cm, annot=True, vmin=0, fmt='g', cmap='Blues', cbar=False)       
        plt.xticks(np.arange(length)+.5, classes, rotation= 90)
        plt.yticks(np.arange(length)+.5, classes, rotation=0)
        plt.xlabel("Predicted")
        plt.ylabel("Actual")
        plt.title("Confusion Matrix")
        plt.show()
    clr = classification_report(y_true, y_pred, target_names=classes)
    print("Classification Report:\n----------------------\n", clr)

# %% [markdown]
# ### evaluate model on the test set then save the model

# %%
tr_plot(history,0)
save_dir=r'./'
subject='Skenario2'
test_results = model.evaluate(test_gen, batch_size=test_batch_size, verbose=1, steps=test_steps, return_dict=True)

# Extract the relevant metrics
test_loss = test_results['loss']
test_accuracy = test_results['accuracy']
val_loss = history.history['val_loss'][-1]
val_accuracy = history.history['val_accuracy'][-1]

# Print the results in color
msg = f'Accuracy on the test set is {test_accuracy * 100:.2f}%, Test Loss: {test_loss:.4f}, Validation Loss: {val_loss:.4f}, Validation Accuracy: {val_accuracy:.4f}'
print_in_color(msg, (0, 255, 0), (55, 65, 80))

# Save the model
save_id = str(model_name + '-' + subject + '-' + str(test_accuracy * 100)[:str(test_accuracy * 100).rfind('.') + 3] + '.h5')
save_loc = os.path.join(save_dir, save_id)
model.save(save_loc)
# Out:
# 4/4 [==============================] - 41s 10s/step - loss: 0.5955 - accuracy: 0.8600
# Accuracy on the test set is 86.00%, Test Loss: 0.5955, Validation Loss: 1.0007, Validation Accuracy: 0.8700
# /Users/nirwanaamir/Library/Python/3.9/lib/python/site-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %% [markdown]
# ### make predictions on test set and generate confusion matrix and classification report

# %%
print_code=0
preds=model.predict(test_gen) 
print_info( test_gen, preds, print_code, save_dir, subject )
# Out:
# 4/4 [==============================] - 35s 8s/step
# Classification Report:
# ----------------------
#                               precision    recall  f1-score   support
#
#          Ayam Woku (Manado)       0.75      0.86      0.80         7
# Barongko (Sulawesi Selatan)       0.92      0.80      0.86        15
#       Bubur Manado (Manado)       0.88      0.70      0.78        10
#    Cakalang Pampis (Manado)       1.00      0.40      0.57         5
#    Coto Makassar (Makassar)       0.53      0.91      0.67        11
#        Deppa Tori_ (Toraja)       1.00      1.00      1.00        12
#  Jagung Marning (Bulukumba)       1.00      0.83      0.91        12
#           Kapurung (Palopo)       0.86      0.86      0.86         7
#          Kasuami (Wakatobi)       1.00      0.88      0.93         8
#            Konro (Makassar)       0.92      0.79      0.85        14
#    Kue Tetu(Sulawesi Barat)       1.00      1.00      1.00        12
#    Lalampa(Sulawesi Tengah)       0.91      0.91      0.91        11
#           Lapa-Lapa (Buton)       1.00      1.00      1.00         7
#          Lawa Bale (Palopo)       0.88      0.88      0.88         8
#          Mie Titi(Makassar)       0.89      1.00      0.94         8
#      Nasu Palekko (Pinrang)       0.50      0.54      0.52        13
#           Pa_piong (Toraja)       0.88      0.78      0.82         9
#    Panada (Sulawesi  Utara)       0.89      1.00      0.94         8
#       Pisang Ijo (Makassar)       0.92      1.00      0.96        11
#       klappertaart (Manado)       1.00      1.00      1.00        12
#
#                    accuracy                           0.86       200
#                   macro avg       0.89      0.86      0.86       200
#                weighted avg       0.88      0.86      0.86       200
